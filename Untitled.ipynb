# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    CustomerID           Name                    Email  Age  Gender
# 0           0   Kayla Howell                      NaN  112    Male  \
# 1           1   Wanda Graham  brianfisher@example.com   65  Female
# 2           2  Raymond James    brownfred@example.com   21    Male
# 3           3   Thomas Smith  anthonyleon@example.com   68  Female
# 4           4    Matthew Lee      david54@example.org   66  Female
#
#            Location  ProductID      Category    Subcategory   Price  ...
# 0     Lake Benjamin          0  Electronics©  Smart Watches  384.37  ...  \
# 1       West Joshua          1   Electronics        Cameras  331.40  ...
# 2        Sweeneyton          2   Electronics  Mobile Phones  534.75  ...
# 3      Lake Matthew          3     Furniture       Cabinets  259.52  ...
# 4  West Kristinbury          4      Clothing       T-Shirts  800.64  ...
#
#    StockLevel RestockThreshold  LastRestockDate WarehouseID
# ...

# %%
df.shape
# Out:
# (9999, 28)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Name', 'Email', 'Age', 'Gender', 'Location', 'ProductID',
#        'Category', 'Subcategory', 'Price', 'Weight', 'Dimensions', 'OrderID',
#        'Date_Order', 'TotalAmount', 'ShippingMethod', 'Status', 'InventoryID',
#        'StockLevel', 'RestockThreshold', 'LastRestockDate', 'WarehouseID',
#        'Location_warehouse', 'Capacity', 'SupplierID', 'Company',
#        'Location_Supplier', 'QualityScore'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          9999 non-null   int64
#  1   Name                9999 non-null   object
#  2   Email               9899 non-null   object
#  3   Age                 9999 non-null   int64
#  4   Gender              9999 non-null   object
#  5   Location            9999 non-null   object
#  6   ProductID           9999 non-null   int64
#  7   Category            9999 non-null   object
#  8   Subcategory         9999 non-null   object
#  9   Price               9999 non-null   float64
#  10  Weight              9999 non-null   float64
#  11  Dimensions          9999 non-null   object
#  12  OrderID             9999 non-null   int64
#  13  Date_Order          9999 non-null   object
#  14  TotalAmount         9999 non-null   object
# ...

# %%
df.describe()
# Out:
#         CustomerID          Age    ProductID        Price       Weight
# count  9999.000000  9999.000000  9999.000000  9999.000000  9999.000000  \
# mean   4999.000000    44.445545    10.851085   500.500877    25.366433
# std    2886.607005    16.238477    11.452692   284.881788    14.327457
# min       0.000000    -7.000000     0.000000     5.020000     0.500000
# 25%    2499.500000    31.000000     3.000000   254.710000    12.770000
# 50%    4999.000000    44.000000     9.000000   501.010000    25.480000
# 75%    7498.500000    57.000000    13.000000   746.345000    37.785000
# max    9998.000000   191.000000    48.000000   999.830000    50.000000
#
#            OrderID  InventoryID   StockLevel  RestockThreshold  WarehouseID
# count  9999.000000  9999.000000  9999.000000       9999.000000  9999.000000  \
# mean   4999.000000  4999.000000   498.626963        253.219222   248.341434
# std    2886.607005  2886.607005   290.985261        141.788026   143.145750
# ...

# %%
dfn = pd.read_csv("data.csv", usecols = ['CustomerID', 'Name', 'Email', 'Age', 'Gender', 'Location', 'ProductID',
       'Category', 'Subcategory', 'Price', 'Weight', 'Dimensions', 'OrderID',
       'Date_Order', 'TotalAmount', 'ShippingMethod', 'Status'])

# %%
dfn.head(20)
# Out:
#     CustomerID             Name                    Email  Age  Gender
# 0            0     Kayla Howell                      NaN  112    Male  \
# 1            1     Wanda Graham  brianfisher@example.com   65  Female
# 2            2    Raymond James    brownfred@example.com   21    Male
# 3            3     Thomas Smith  anthonyleon@example.com   68  Female
# 4            4      Matthew Lee      david54@example.org   66  Female
# 5            5    Charles Davis    charles60@example.com   27  Female
# 6            6   Michael Gordon   hallashley@example.com   30    Male
# 7            7      Alicia Wood      ovargas@example.org   19    Male
# 8            8   Jason Mcdaniel    phamilton@example.com   52    Male
# 9            9   Ernest Sherman      molly51@example.com   66  Female
# 10          10      Diana Moore     diazlori@example.org   68  Female
# 11          11    Sara Lawrence   davidhayes@example.com   40    Male
# ...

# %%
dfm = pd.read_csv("data.csv", usecols = ['InventoryID',
       'StockLevel', 'RestockThreshold', 'LastRestockDate', 'WarehouseID',
       'Location_warehouse', 'Capacity', 'SupplierID', 'Company',
       'Location_Supplier', 'TotalAmount'])

# %%
dfm.sample(20)
# Out:
#      TotalAmount  InventoryID  StockLevel  RestockThreshold LastRestockDate
# 7374    €1063.78         7374         501                76      2020-09-28  \
# 326     €1025.85          326         600               471      2022-02-07
# 4500    $4981.15         4500         319               500      2022-06-09
# 4301     $898.63         4301         274               388      2021-07-02
# 3075     £296.52         3075         747               311      2021-11-11
# 9695     $120.68         9695         412                71      2021-05-08
# 2939      €52.02         2939         198               174      2022-04-13
# 8871     $683.19         8871         173               462      2022-08-03
# 4212    $3341.44         4212         899               351      2021-09-04
# 6413     $246.23         6413         627               100      2020-12-03
# 2138    £1104.36         2138         304               389      2021-11-06
# ...

# %%
df.Status.unique()
# Out:
# array(['Pending', 'Cancelled', 'Shipped', 'Delivered'], dtype=object)

# %%
df.sample(20)
# Out:
#       CustomerID               Name                        Email  Age  Gender
# 4373        4373     Taylor Wheeler           klewis@example.com   63    Male  \
# 8654        8654         Adam Banks           cstone@example.org   41    Male
# 543          543     Krystal Benson          icherry@example.org   49  Female
# 5540        5540   Jennifer Johnson     rebeccacohen@example.net   30    Male
# 9822        9822       Natasha Hall     kevinmathews@example.com   39  Female
# 6512        6512         Todd Mejia      carrwilliam@example.net   40    Male
# 5351        5351  Brandon Armstrong        hillhaley@example.com   35    Male
# 827          827     Deanna Simpson          blake63@example.com   45    Male
# 7433        7433      Jason Jenkins       markwalton@example.net   23  Female
# 7385        7385      Ricky Woodard      cynthiahull@example.com   27    Male
# 2705        2705       Wendy Orozco        daviskyle@example.net   65  Female
# ...

# %%
df.Dimensions.nunique()
# Out:
# 9609

# %%
df.SupplierID.unique()
# Out:
# array([2, 8, 5, 0, 9, 7, 1, 3, 6, 4], dtype=int64)
